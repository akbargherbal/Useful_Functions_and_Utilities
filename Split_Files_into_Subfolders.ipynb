# %%
import os
import shutil

def split_files_by_number_of_files_per_folder(directory_path, max_files_per_folder, file_extension=".pdf"):
    """
    Splits files in the specified directory into subfolders based on the maximum number of files per folder.
    Each subfolder will contain a maximum of `max_files_per_folder` files.
    Files with the specified `file_extension` will be moved into subfolders.
    """
    # create subfolders
    file_counter = 0
    while True:
        folder_name = f"{file_counter:03}-{file_counter+max_files_per_folder-1:03}"
        folder_path = os.path.join(directory_path, folder_name)
        os.makedirs(folder_path, exist_ok=True)
        files_in_folder = 0
        # move files to subfolder
        for filename in os.listdir(directory_path):
            if filename.endswith(file_extension):
                file_number = int(filename.split(".")[0])
                if file_number >= file_counter and file_number < file_counter + max_files_per_folder:
                    file_path = os.path.join(directory_path, filename)
                    new_file_path = os.path.join(folder_path, filename)
                    shutil.move(file_path, new_file_path)
                    files_in_folder += 1
        # if no files were moved to subfolder, break the loop
        if files_in_folder == 0:
            break
        file_counter += max_files_per_folder

# %%
directory_path = "zahra_split/"
max_files_per_folder = 45
file_extension = ".pdf"

# %%
#split_files_by_number_of_files_per_folder(directory_path, max_files_per_folder, file_extension)

# %%
# !gsutil -m cp -r zahra_split/ gs://akbar-usa/Document_AI/MAIN/ZAHRA
# Out:
# Copying file://zahra_split/045-089/045.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/073.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/066.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/054.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/067.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/058.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/086.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/088.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/060.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/070.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/064.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/078.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/048.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/084.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/049.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/055.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/053.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/079.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/075.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/085.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/077.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/062.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/056.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/047.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/083.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/057.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/074.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/068.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/080.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/087.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/050.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/076.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/082.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/052.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/063.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/069.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/061.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/046.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/051.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/072.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/071.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/089.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/059.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/081.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/113.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/090.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/045-089/065.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/120.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/119.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/098.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/107.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/095.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/127.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/129.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/099.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/130.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/110.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/111.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/132.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/124.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/125.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/123.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/108.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/112.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/091.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/094.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/131.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/101.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/100.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/093.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/096.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/117.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/114.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/092.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/121.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/133.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/109.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/118.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/116.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/104.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/097.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/102.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/126.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/106.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/105.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/128.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/134.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/103.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/115.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/031.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/090-134/122.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/018.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/019.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/038.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/022.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/002.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/014.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/016.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/028.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/037.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/009.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/042.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/034.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/040.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/001.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/035.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/006.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/010.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/023.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/036.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/011.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/005.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/032.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/029.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/020.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/004.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/044.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/030.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/025.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/013.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/008.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/015.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/003.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/021.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/007.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/000.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/012.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/027.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/033.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/039.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/017.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/041.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/024.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/026.pdf [Content-Type=application/pdf]...
# Copying file://zahra_split/000-044/043.pdf [Content-Type=application/pdf]...
# - [135/135 files][ 45.9 MiB/ 45.9 MiB] 100% Done
# Operation completed over 135 objects/45.9 MiB.
